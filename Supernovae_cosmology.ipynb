# %% [markdown]
# <a href="https://colab.research.google.com/github/KOZlegend/Dark-Matter/blob/Supernovae/Supernovae_cosmology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import astropy.io.ascii
import astropy.units as u
import astropy.constants as ac

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-35aaa5de-e8f7-4d5b-8288-a3529488e936" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35aaa5de-e8f7-4d5b-8288-a3529488e936">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dat = astropy.io.ascii.read("Tonry_2003.vot")
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
distance = 10**dat["col8"] / 72.0 * u.mpc
distance_error = (10**(dat["col8"]+dat["col9"]) - 10**dat["col8"]) / 72.0 * u.mpc
velocity = 10**dat["col7"] * u.km / u.s
plt.plot(distance.to(u.mpc).value, velocity.to(u.km / u.s).value, marker=".", color="black", linestyle="none")
plt.xscale("log") # plot as logarithmic function
plt.yscale("log") # plot as logarithmic function
plt.xlabel("Distance [Mpc]")
plt.ylabel("Velocity [km/s]")
# Out:
# Text(0, 0.5, 'Velocity [km/s]')

# %%
distance = 10**dat["col8"] / 72.0 * u.mpc # plot linearly for a smaller scale
velocity = 10**dat["col7"] * u.km / u.s # plot linearly for a smaller scale
plt.errorbar(distance.to(u.mpc).value, velocity.to(u.km / u.s).value, xerr=distance_error.to(u.mpc).value, marker=".", color="black", linestyle="none") # plot error bars
plt.xlim(0, 700)
plt.ylim(0, 4e4)
plt.xlabel("Distance [Mpc]")
plt.ylabel("Velocity [km/s]")
# break plot to determine if the slope is constant
# Out:
# Text(0, 0.5, 'Velocity [km/s]')

# %% [markdown]
# https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html

# %%
x = distance.to(u.mpc).value
ind = np.where((x > 0) & (x < 700)) # gives index of x-array where x is larger than 0 and smaller than 700
z = np.polyfit(distance.to(u.mpc).value[ind], velocity.to(u.km / u.s).value[ind], 1) # least squares polynomial fit between x and y values

# %%
p = np.poly1d(z) # fits polynomial coefficient

# %%
velocity_model = p(distance.to(u.mpc).value) # evaluate velocity using linear relationship to distance

# %%
plt.errorbar(distance.to(u.mpc).value, velocity.to(u.km / u.s).value, xerr=distance_error.to(u.mpc).value, marker=".", color="black", linestyle="none")
plt.plot(distance.to(u.mpc).value, velocity_model, color="grey", linewidth=5) # plot line
plt.xlim(0, 700)
plt.ylim(0, 4e4)
plt.xlabel("Distance [Mpc]")
plt.ylabel("Velocity [km/s]")
plt.annotate(r"$H_0$ = {0:5.2f} km/s/Mpc".format(z[0]), xy=(50, 30000)) # report value of line
# Out:
# Text(50, 30000, '$H_0$ = 67.48 km/s/Mpc')

# %%
distance = 10**dat["col8"] / 72.0 * u.mpc # plot linearly for a smaller scale
velocity = 10**dat["col7"] * u.km / u.s # plot linearly for a smaller scale
plt.errorbar(distance.to(u.mpc).value, velocity.to(u.km / u.s).value, xerr=distance_error.to(u.mpc).value, marker=".", color="black", linestyle="none") # plot error bars
plt.xlim(0, 400)
plt.ylim(0, 2e4)
plt.xlabel("Distance [Mpc]")
plt.ylabel("Velocity [km/s]")
# break plot to determine if the slope is constant
# Out:
# Text(0, 0.5, 'Velocity [km/s]')

# %%
p = np.poly1d(z) # fits polynomial coefficient

# %%
x = distance.to(u.mpc).value
ind = np.where((x > 0) & (x < 400)) # gives index of x-array where x is larger than 0 and smaller than 400
z = np.polyfit(distance.to(u.mpc).value[ind], velocity.to(u.km / u.s).value[ind], 1) # least squares polynomial fit between x and y values

# %%
velocity_model = p(distance.to(u.mpc).value) # evaluate velocity using linear relationship to distance

# %%
plt.errorbar(distance.to(u.mpc).value, velocity.to(u.km / u.s).value, xerr=distance_error.to(u.mpc).value, marker=".", color="black", linestyle="none")
plt.plot(distance.to(u.mpc).value, velocity_model, color="grey", linewidth=5) # plot line
plt.xlim(0, 400)
plt.ylim(0, 2e4)
plt.xlabel("Distance [Mpc]")
plt.ylabel("Velocity [km/s]")
plt.annotate(r"$H_0$ = {0:5.2f} km/s/Mpc".format(z[0]), xy=(250, 10000)) # report value of line
# Out:
# Text(250, 10000, '$H_0$ = 68.63 km/s/Mpc')

# %%
distance = 10**dat["col8"] / 72.0 * u.mpc # plot linearly for a smaller scale
velocity = 10**dat["col7"] * u.km / u.s # plot linearly for a smaller scale
plt.errorbar(distance.to(u.mpc).value, velocity.to(u.km / u.s).value, xerr=distance_error.to(u.mpc).value, marker=".", color="black", linestyle="none") # plot error bars
plt.xlim(1500, 5000)
plt.ylim(1e5, 2e5)
plt.xlabel("Distance [Mpc]")
plt.ylabel("Velocity [km/s]")
# break plot to determine if the slope is constant
# Out:
# Text(0, 0.5, 'Velocity [km/s]')

# %%
p = np.poly1d(z) # fits polynomial coefficient

# %%
x = distance.to(u.mpc).value
ind = np.where((x > 1500) & (x < 5000)) # gives index of x-array where x is larger than 1500 and smaller than 5000
z = np.polyfit(distance.to(u.mpc).value[ind], velocity.to(u.km / u.s).value[ind], 1) # least squares polynomial fit between x and y values

# %%
velocity_model = p(distance.to(u.mpc).value) # evaluate velocity using linear relationship to distance

# %%
plt.errorbar(distance.to(u.mpc).value, velocity.to(u.km / u.s).value, xerr=distance_error.to(u.mpc).value, marker=".", color="black", linestyle="none")
plt.plot(distance.to(u.mpc).value, velocity_model, color="grey", linewidth=5) # plot line
plt.xlim(1500, 5000)
plt.ylim(1e5, 2e5)
plt.xlabel("Distance [Mpc]")
plt.ylabel("Velocity [km/s]")
plt.annotate(r"$H_0$ = {0:5.2f} km/s/Mpc".format(z[0]), xy=(3750, 140000)) # report value of line
# Out:
# Text(3750, 140000, '$H_0$ = 35.03 km/s/Mpc')

# %% [markdown]
# https://emcee.readthedocs.io/en/stable/tutorials/line/

# %%
x = velocity.to(u.km / u.s).value[ind]
y = distance.to(u.mpc).value[ind]
yerr = distance_error.to(u.mpc).value[ind]

plt.errorbar(x, y, yerr=yerr, marker=".", color="black", linestyle="none")
# plt.ylim(0, 700)
# plt.xlim(0, 4e4)
plt.ylabel("Distance [Mpc]")
plt.xlabel("Velocity [km/s]")
# Out:
# Text(0.5, 0, 'Velocity [km/s]')

# %%
x0 = np.linspace(0, 50000, 500)

A = np.vander(x, 2)
C = np.diag(yerr * yerr)
ATA = np.dot(A.T, A / (yerr**2)[:, None])
cov = np.linalg.inv(ATA)
w = np.linalg.solve(ATA, np.dot(A.T, y / yerr**2))
print("Least-squares estimates:")
print("m = {0:.3f} ± {1:.3f}".format(w[0], np.sqrt(cov[0, 0])))
print("b = {0:.3f} ± {1:.3f}".format(w[1], np.sqrt(cov[1, 1])))

plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.plot(x0, np.dot(np.vander(x0, 2), w), "--k", label="LS")
plt.legend(fontsize=14)
plt.ylabel("Distance [Mpc]")
plt.xlabel("Velocity [km/s]");
# Out:
# Least-squares estimates:
# m = 0.015 ± 0.000
# b = -6.338 ± 0.219

# %%
def log_likelihood(theta, x, y, yerr):
    m, b, log_f = theta
    model = m * x + b
    sigma2 = yerr**2 + model**2 * np.exp(2 * log_f)
    return -0.5 * np.sum((y - model) ** 2 / sigma2 + np.log(sigma2))

# %%
from scipy.optimize import minimize

np.random.seed(42)
nll = lambda *args: -log_likelihood(*args)
initial = np.array([1 / 72.0, 0.0, np.log(1.0)]) + 0.1 * np.random.randn(3)
soln = minimize(nll, initial, args=(x, y, yerr))
m_ml, b_ml, log_f_ml = soln.x

print("Maximum likelihood estimates:")
print("m = {0:.3f}".format(m_ml))
print("b = {0:.3f}".format(b_ml))
print("f = {0:.3f}".format(np.exp(log_f_ml)))

plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.plot(x0, np.dot(np.vander(x0, 2), w), "--k", label="LS")
plt.plot(x0, np.dot(np.vander(x0, 2), [m_ml, b_ml]), ":k", label="ML")
plt.legend(fontsize=14)
plt.ylabel("Distance [Mpc]")
plt.xlabel("Velocity [km/s]");
# Out:
# Maximum likelihood estimates:
# m = 0.014
# b = -0.981
# f = 0.167

# %%
def log_prior(theta):
    m, b, log_f = theta
    if 0.0 < m < 0.5 and -100.0 < b < 100.0 and -10.0 < log_f < 1.0:
        return 0.0
    return -np.inf

def log_probability(theta, x, y, yerr):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, x, y, yerr)

# %%
! pip install -U emcee
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import emcee

pos = soln.x + 1e-4 * np.random.randn(32, 3)
nwalkers, ndim = pos.shape

sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(x, y, yerr)
)
sampler.run_mcmc(pos, 5000, progress=True);
# Out:
#  32%|███▏      | 1581/5000 [00:05<00:13, 253.21it/s]

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["m", "b", "log(f)"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
tau = sampler.get_autocorr_time()
print(tau)

# %%
flat_samples = sampler.get_chain(discard=100, thin=15, flat=True)
print(flat_samples.shape)

# %%
! pip install corner

# %%
import corner

fig = corner.corner(flat_samples, labels=labels);

# %%
inds = np.random.randint(len(flat_samples), size=100)
for ind in inds:
    sample = flat_samples[ind]
    plt.plot(x0, np.dot(np.vander(x0, 2), sample[:2]), "C1", alpha=0.1)
plt.errorbar(x, y, yerr=yerr, fmt=".k", capsize=0)
plt.plot(x0, np.dot(np.vander(x0, 2), w), "--k", label="LS")
plt.plot(x0, np.dot(np.vander(x0, 2), [m_ml, b_ml]), ":k", label="ML")
plt.legend(fontsize=14)
plt.ylabel("Distance [Mpc]")
plt.xlabel("Velocity [km/s]");

# %%
from IPython.display import display, Math

for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.5f}_{{-{1:.5f}}}^{{{2:.5f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
